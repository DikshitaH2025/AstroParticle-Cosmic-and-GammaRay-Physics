# %% [markdown]
# # Event reconstruction for mono analysis
#
# Our aim is to find the Hillas paramters for a simple monoscopic analysis.
# refer to https://ctapipe.readthedocs.io/en/stable/auto_examples/tutorials/ctapipe_overview.html
#
# For the file "gamma-diffuse_with_images_00.dl2.h5"

# %% [markdown]
# Lets start with a bunch of imports...

# %%
import numpy as np
from matplotlib import pyplot as plt
from ctapipe.io import EventSource
from ctapipe.visualization import CameraDisplay, ArrayDisplay
from ctapipe.reco import HillasReconstructor
from ctapipe.image import hillas_parameters, tailcuts_clean, timing_parameters
from ctapipe.image import brightest_island, number_of_islands, largest_island
import math
import astropy.units as u
from astropy.coordinates import SkyCoord, AltAz
from ctapipe.coordinates import CameraFrame
from ctapipe.coordinates.utils import altaz_to_righthanded_cartesian

# %% [markdown]
# Read the file...

# %%
dl1_file = "gamma-diffuse_with_images_00.dl2.h5"

source = EventSource(
    input_url = dl1_file,
    max_events = None
)
subarray = source.subarray
# Out:
# Table /configuration/simulation/run is missing column None for field run_number of container <class 'ctapipe.containers.SimulationConfigContainer'>. It will be skipped.

# %% [markdown]
# Find all events on any one telescope (lets say TEL_ID = 10)
#
# - How many events are there?

# %% [markdown]
# So we use this TEL_ID to select a telescope and then make a list of all the events that triggered this particular telescope.

# %%
#Selecting one particular telescope for analysis
tel_id = 10

#Defining a list for all its events
mono_events = []

#Iterating through all the events and selecting the ones where the telescope with tel_id has triggered
for event in source:
    if tel_id in event.trigger.tels_with_trigger:
        mono_events.append(event)
# Out:
# Table /dl1/event/telescope/trigger is missing column event_type for field event_type of container <class 'ctapipe.containers.TelescopeTriggerContainer'>. It will be skipped.
# Table /simulation/event/subarray/shower is missing column true_starting_grammage for field starting_grammage of container <class 'ctapipe.containers.SimulatedShowerContainer'>. It will be skipped.
# Table /dl2/event/subarray/geometry/HillasReconstructor is missing column HillasReconstructor_ang_distance_uncert for field ang_distance_uncert of container <class 'ctapipe.containers.ReconstructedGeometryContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_035 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_035 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_035 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_035 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_010 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_010 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_010 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_010 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_011 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_011 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_011 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_011 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_009 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_009 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_009 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_009 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_007 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_007 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_007 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_007 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_005 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_005 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_005 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_005 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_001 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_001 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_001 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_001 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_002 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_002 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_002 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_002 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_008 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_008 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_008 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_008 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_019 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_019 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_019 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_019 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_003 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_003 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_003 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_003 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_004 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_004 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_004 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_004 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_006 is missing column hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /dl1/event/telescope/parameters/tel_006 is missing column hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_006 is missing column true_hillas_psi_uncertainty for field psi_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.
# Table /simulation/event/telescope/parameters/tel_006 is missing column true_hillas_transverse_cog_uncertainty for field transverse_cog_uncertainty of container <class 'ctapipe.containers.HillasParametersContainer'>. It will be skipped.

# %%
#Printing the number of events where the telescope with tel_id has triggered
print(f"Number of events where telescope {tel_id} has triggered: {len(mono_events)}")
# Out:
# Number of events where telescope 10 has triggered: 7570

# %%
# You can find the image data in the dl1 file
mono_events[0].dl1.tel[tel_id].image
# Out:
# array([ 1.2, -1.3, -1.1, ...,  0.4, -0.6,  2.7],
#       shape=(1855,), dtype=float32)

# %%
#printing the attributes of the mono_events list
print(f"Attributes of mono_events list: {dir(mono_events)}")
# Out:
# Attributes of mono_events list: ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %% [markdown]
# - Plot the image for different event ids
# - Clean the image using `tailcuts_clean` (use event id = 5) - How to decide thresholds?
# - Find the number of islands
# - get the brightest island
# - compute the Hillas parameters
# - overlay the Hillas parameters on the plot
# - Plot the arrival time at each pixel
# - compute the timing profile using `timing_parameters`
# - Repeat for another few events to get a feel
# - Now, repeat for all events (for performance issues, use ~1000 events)
# - Find the simulated energy value for each event
# - Plot the Hillas/timing parameters with energy - The n

# %% [markdown]
# #### Plotting the image for different event_ids

# %%
N=np.random.randint(0, len(mono_events), 5)
for i in N:
    event = mono_events[i]
    image = event.dl1.tel[tel_id].image #Conatins all the intesnity info
    geom = subarray.tel[tel_id].camera.geometry #Contains all x,y coordinates

    disp = CameraDisplay(geom, image=image)
    disp.add_colorbar()
    #Adding a title to the plot
    plt.title(f"Event ID: {event.index.event_id}")
    plt.show()

# %% [markdown]
# #### Clean the image using `tailcuts_clean` (use event id = 5) - How to decide thresholds?
# #### Finding the number of island and the brightest island.
# #### Finding the Hillas Parameter.
#
# Here we have picture_threh -> strong pixels and
# boundary_tresh -> weaker neighbours
#
# We can decide the threshold by looking the hight intensity pixel and noting which minimum surrounding pixel intensity gives us the best shape of the shower.

# %%
#Plotting the initial image without any clean up
event_5=mono_events[5]
image_5 = event_5.dl1.tel[tel_id].image #considering only the 5th event for analysis
geom = subarray.tel[tel_id].camera.geometry
disp = CameraDisplay(geom, image=image_5)
disp.add_colorbar()
plt.title(f"Event ID: {event_5.index.event_id} without cleaning")
plt.show()

#Adding the cleaned image
#This is to remove the noise pixels
clean_mask = tailcuts_clean(geom, image_5, picture_thresh=10, boundary_thresh=5)
#picture_thresh is to select the strongest pixel in the image. 
#boundary_thresh comsiders the min imtensity of the pixels surrounding the main shower.
clean_image_5 = image_5.copy()
clean_image_5[~clean_mask] = 0

disp = CameraDisplay(geom, image=clean_image_5)
disp.add_colorbar()

plt.title(f"Event ID: {event_5.index.event_id} cleaned image")
plt.show()



#Finding the number of islands in the image
n_islands_5, island_labels_5 = number_of_islands(geom, clean_mask)
print(f"Number of islands in the image: {n_islands_5}")

#Saving the brightest island in the image
#The brightest island is the one with the highest total pixel intensity
mask_5 = largest_island(island_labels_5)


#combining the mask of the brightest island with the clean mask to get the final mask
final_mask_5 = clean_mask & mask_5

#Computing the hillas parameters of the brightest island
hillas_5 = hillas_parameters(geom[final_mask_5], image_5[final_mask_5])
print(f"Hillas parameters of the brightest island: {hillas_5}")

#Plotting the cleaned image with the hillas parameters
disp = CameraDisplay(geom, image=clean_image_5)
disp.overlay_moments(hillas_5)
disp.add_colorbar()
plt.title(f"Event ID: {event_5.index.event_id} cleaned image with hillas parameters")
plt.show()
# Out:
# Number of islands in the image: 1
# Hillas parameters of the brightest island: {'intensity': np.float64(152.89999866485596),
#  'kurtosis': np.float64(1.8610171221208414),
#  'length': <Quantity 0.08457558 m>,
#  'length_uncertainty': <Quantity 0.00317334 m>,
#  'phi': <Angle -0.5367505 rad>,
#  'psi': <Angle 1.0281727 rad>,
#  'psi_uncertainty': <Angle 0.05619546 rad>,
#  'r': <Quantity 0.77521606 m>,
#  'skewness': np.float64(-0.34086483382918864),
#  'transverse_cog_uncertainty': <Quantity 0.00368772 m>,
#  'width': <Quantity 0.0265511 m>,
#  'width_uncertainty': <Quantity 0.0014784 m>,
#  'x': <Quantity 0.66620118 m>,
#  'y': <Quantity -0.39640376 m>}

# %%
#Plotting the initial image without any clean up
event=mono_events[11]
image = event.dl1.tel[tel_id].image #considering only the 1st event for analysis
geom = subarray.tel[tel_id].camera.geometry

#This is to remove the noise pixels
clean_mask = tailcuts_clean(geom, image, picture_thresh=10, boundary_thresh=4)
clean_image = image.copy()
clean_image[~clean_mask] = 0

disp = CameraDisplay(geom, image=clean_image)
disp.add_colorbar()

plt.title(f"Event ID: {event.index.event_id} cleaned image")
plt.show()


#Finding the number of islands in the image
n_islands, island_labels = number_of_islands(geom, clean_mask)
print(f"Number of islands in the image: {n_islands}\n")

#Saving the brightest island in the image
#The brightest island is the one with the highest total pixel intensity
mask = largest_island(island_labels)


#combining the mask of the brightest island with the clean mask to get the final mask
final_mask = clean_mask & mask

#Cleaning the image to only keep the pixels in the brightest island
clean_image_final = image.copy()
clean_image_final[~final_mask] = 0

#Computing the hillas parameters of the brightest island
hillas = hillas_parameters(geom[final_mask], image[final_mask])
print(f"Hillas parameters of the brightest island: {hillas}")
# Out:
# Number of islands in the image: 3
#
# Hillas parameters of the brightest island: {'intensity': np.float64(128.10000085830688),
#  'kurtosis': np.float64(1.788192251069855),
#  'length': <Quantity 0.07007769 m>,
#  'length_uncertainty': <Quantity 0.00274847 m>,
#  'phi': <Angle 3.13447776 rad>,
#  'psi': <Angle 0.75724483 rad>,
#  'psi_uncertainty': <Angle 0.08459637 rad>,
#  'r': <Quantity 0.82144413 m>,
#  'skewness': np.float64(0.10117541036220776),
#  'transverse_cog_uncertainty': <Quantity 0.0040289 m>,
#  'width': <Quantity 0.02684308 m>,
#  'width_uncertainty': <Quantity 0.00149784 m>,
#  'x': <Quantity -0.82142333 m>,
#  'y': <Quantity 0.00584444 m>}

# %% [markdown]
# #### Overlaying the Hillas Parameter

# %%
disp = CameraDisplay(geom, image=clean_image_final)
disp.overlay_moments(hillas)
disp.add_colorbar()

plt.title(f"Event ID: {event.index.event_id} cleaned image")
plt.show()

# %% [markdown]
# #### Plotting the arrival time of each pixel and the timing profile

# %% [markdown]
# So we have this CameraDIsplay fucntion that can take an image and plot it and we have already used it to plot the intensity of each pixel and now we can do the same using the peak time from the events.
# We will take the peak time from one event and this stores all the time of arrival of each pixel.

# %%
peak_time=event.dl1.tel[tel_id].peak_time

disp = CameraDisplay(geom, image=peak_time)
disp.add_colorbar()
plt.title(f"Event ID: {event.index.event_id} peak time")
plt.show()

# %% [markdown]
# #### Timing Parameters -
# Slope - time gradient along the shower axis (how quickly arrival time changes along the image)$\\$
# Deviation - time offset at the shower centroid (larger deviation => noisy and irregular shower)

# %%
#Now for the timing profile we basically compute the time gradient along the Hillas axis.

timing = timing_parameters(geom,image=clean_image_final,peak_time=peak_time,hillas_parameters=hillas)
print(f"Timing parameters: {timing}")
# Out:
# Timing parameters: {'deviation': 18.15522885361112,
#  'intercept': np.float64(23.41768571610639),
#  'slope': <Quantity 10.96784054 1 / m>}

# %% [markdown]
# geom → camera geometry
# image → pixel brightness
# peak_time → arrival times
# hillas → previously computed Hillas parameters
# mask → cleaned pixels
# $\\$
# image ->
# clean image ->
# find islands ->
# select brightest island ->
# Hillas parameters ->
# timing parameters

# %%
# Loop through all mono events and find number of islands

for i, event in enumerate(mono_events):

    image = event.dl1.tel[tel_id].image
    geom = subarray.tel[tel_id].camera.geometry

    # Tailcuts cleaning
    clean_mask = tailcuts_clean(geom, image, picture_thresh=10, boundary_thresh=5)

    # Find islands
    n_islands, island_labels = number_of_islands(geom, clean_mask)

    print(f"Event {i+1} (Event ID: {event.index.event_id}) -> Number of islands: {n_islands}")
# Out:
# Event 1 (Event ID: 74804) -> Number of islands: 1
# Event 2 (Event ID: 165408) -> Number of islands: 3
# Event 3 (Event ID: 165410) -> Number of islands: 0
# Event 4 (Event ID: 178009) -> Number of islands: 1
# Event 5 (Event ID: 178016) -> Number of islands: 1
# Event 6 (Event ID: 306015) -> Number of islands: 1
# Event 7 (Event ID: 330713) -> Number of islands: 1
# Event 8 (Event ID: 397919) -> Number of islands: 1
# Event 9 (Event ID: 559900) -> Number of islands: 1
# Event 10 (Event ID: 576707) -> Number of islands: 1
# Event 11 (Event ID: 576709) -> Number of islands: 2
# Event 12 (Event ID: 576713) -> Number of islands: 3
# Event 13 (Event ID: 616707) -> Number of islands: 1
# Event 14 (Event ID: 675901) -> Number of islands: 1
# Event 15 (Event ID: 676111) -> Number of islands: 1
# Event 16 (Event ID: 679013) -> Number of islands: 1
# Event 17 (Event ID: 691504) -> Number of islands: 1
# Event 18 (Event ID: 702400) -> Number of islands: 1
# Event 19 (Event ID: 706418) -> Number of islands: 1
# Event 20 (Event ID: 706907) -> Number of islands: 1
# Event 21 (Event ID: 706909) -> Number of islands: 1
# Event 22 (Event ID: 764212) -> Number of islands: 2
# Event 23 (Event ID: 771401) -> Number of islands: 1
# Event 24 (Event ID: 771403) -> Number of islands: 1
# Event 25 (Event ID: 781314) -> Number of islands: 1
# Event 26 (Event ID: 826500) -> Number of islands: 1
# Event 27 (Event ID: 828508) -> Number of islands: 1
# Event 28 (Event ID: 868004) -> Number of islands: 1
# Event 29 (Event ID: 932702) -> Number of islands: 1
# Event 30 (Event ID: 934201) -> Number of islands: 0
# Event 31 (Event ID: 940004) -> Number of islands: 2
# Event 32 (Event ID: 992901) -> Number of islands: 2
# Event 33 (Event ID: 992919) -> Number of islands: 1
# Event 34 (Event ID: 1040008) -> Number of islands: 1
# Event 35 (Event ID: 1044111) -> Number of islands: 1
# Event 36 (Event ID: 1057412) -> Number of islands: 3
# Event 37 (Event ID: 1080700) -> Number of islands: 1
# Event 38 (Event ID: 1080718) -> Number of islands: 2
# Event 39 (Event ID: 1090801) -> Number of islands: 1
# Event 40 (Event ID: 1120201) -> Number of islands: 1
# Event 41 (Event ID: 1145105) -> Number of islands: 1
# Event 42 (Event ID: 1146610) -> Number of islands: 1
# Event 43 (Event ID: 1154805) -> Number of islands: 1
# Event 44 (Event ID: 1154813) -> Number of islands: 2
# Event 45 (Event ID: 1205209) -> Number of islands: 1
# Event 46 (Event ID: 1248113) -> Number of islands: 1
# Event 47 (Event ID: 1276506) -> Number of islands: 1
# Event 48 (Event ID: 1279604) -> Number of islands: 1
# Event 49 (Event ID: 1323615) -> Number of islands: 1
# Event 50 (Event ID: 1334816) -> Number of islands: 1
# Event 51 (Event ID: 1391504) -> Number of islands: 1
# Event 52 (Event ID: 1403216) -> Number of islands: 1
# Event 53 (Event ID: 1455008) -> Number of islands: 1
# Event 54 (Event ID: 1457712) -> Number of islands: 1
# Event 55 (Event ID: 1460205) -> Number of islands: 1
# Event 56 (Event ID: 1485802) -> Number of islands: 1
# Event 57 (Event ID: 1524718) -> Number of islands: 1
# Event 58 (Event ID: 1577716) -> Number of islands: 1
# Event 59 (Event ID: 1585200) -> Number of islands: 2
# Event 60 (Event ID: 1585206) -> Number of islands: 1
# Event 61 (Event ID: 1641017) -> Number of islands: 1
# Event 62 (Event ID: 1645001) -> Number of islands: 1
# Event 63 (Event ID: 1645012) -> Number of islands: 1
# Event 64 (Event ID: 1672310) -> Number of islands: 2
# Event 65 (Event ID: 1672316) -> Number of islands: 1
# Event 66 (Event ID: 1687705) -> Number of islands: 1
# Event 67 (Event ID: 1785802) -> Number of islands: 1
# Event 68 (Event ID: 1786004) -> Number of islands: 1
# Event 69 (Event ID: 1786012) -> Number of islands: 1
# Event 70 (Event ID: 1788007) -> Number of islands: 2
# Event 71 (Event ID: 1809505) -> Number of islands: 1
# Event 72 (Event ID: 1817717) -> Number of islands: 1
# Event 73 (Event ID: 1920104) -> Number of islands: 1
# Event 74 (Event ID: 2003514) -> Number of islands: 1
# Event 75 (Event ID: 2018207) -> Number of islands: 1
# Event 76 (Event ID: 2034007) -> Number of islands: 1
# Event 77 (Event ID: 2079202) -> Number of islands: 2
# Event 78 (Event ID: 2132015) -> Number of islands: 1
# Event 79 (Event ID: 2132018) -> Number of islands: 1
# Event 80 (Event ID: 2145501) -> Number of islands: 1
# Event 81 (Event ID: 2145515) -> Number of islands: 1
# Event 82 (Event ID: 2160103) -> Number of islands: 2
# Event 83 (Event ID: 2170613) -> Number of islands: 1
# Event 84 (Event ID: 2180019) -> Number of islands: 1
# Event 85 (Event ID: 2216410) -> Number of islands: 2
# Event 86 (Event ID: 2235314) -> Number of islands: 3
# Event 87 (Event ID: 2238113) -> Number of islands: 1
# Event 88 (Event ID: 2258804) -> Number of islands: 1
# Event 89 (Event ID: 2271106) -> Number of islands: 1
# Event 90 (Event ID: 2310107) -> Number of islands: 1
# Event 91 (Event ID: 2334809) -> Number of islands: 1
# Event 92 (Event ID: 2340902) -> Number of islands: 2
# Event 93 (Event ID: 2340916) -> Number of islands: 2
# Event 94 (Event ID: 2349206) -> Number of islands: 2
# Event 95 (Event ID: 2366110) -> Number of islands: 1
# Event 96 (Event ID: 2518313) -> Number of islands: 1
# Event 97 (Event ID: 2532318) -> Number of islands: 1
# Event 98 (Event ID: 2544205) -> Number of islands: 0
# Event 99 (Event ID: 2553204) -> Number of islands: 1
# Event 100 (Event ID: 2592811) -> Number of islands: 1
# Event 101 (Event ID: 2605813) -> Number of islands: 7
# Event 102 (Event ID: 2605816) -> Number of islands: 1
# Event 103 (Event ID: 2683607) -> Number of islands: 1
# Event 104 (Event ID: 2684401) -> Number of islands: 1
# Event 105 (Event ID: 2684412) -> Number of islands: 1
# Event 106 (Event ID: 2717511) -> Number of islands: 1
# Event 107 (Event ID: 2867402) -> Number of islands: 1
# Event 108 (Event ID: 2867408) -> Number of islands: 1
# Event 109 (Event ID: 2867416) -> Number of islands: 1
# Event 110 (Event ID: 3011506) -> Number of islands: 1
# Event 111 (Event ID: 3075917) -> Number of islands: 1
# Event 112 (Event ID: 3112419) -> Number of islands: 1
# Event 113 (Event ID: 3186203) -> Number of islands: 1
# Event 114 (Event ID: 3188805) -> Number of islands: 1
# Event 115 (Event ID: 3209618) -> Number of islands: 1
# Event 116 (Event ID: 3357508) -> Number of islands: 1
# Event 117 (Event ID: 3441318) -> Number of islands: 1
# Event 118 (Event ID: 3514807) -> Number of islands: 1
# Event 119 (Event ID: 3560317) -> Number of islands: 1
# Event 120 (Event ID: 3588400) -> Number of islands: 1
# Event 121 (Event ID: 3617901) -> Number of islands: 1
# Event 122 (Event ID: 3644613) -> Number of islands: 1
# Event 123 (Event ID: 3705309) -> Number of islands: 1
# Event 124 (Event ID: 3707316) -> Number of islands: 1
# Event 125 (Event ID: 3770408) -> Number of islands: 3
# Event 126 (Event ID: 3813518) -> Number of islands: 1
# Event 127 (Event ID: 3882914) -> Number of islands: 1
# Event 128 (Event ID: 3890812) -> Number of islands: 1
# Event 129 (Event ID: 3911310) -> Number of islands: 1
# Event 130 (Event ID: 3920004) -> Number of islands: 1
# Event 131 (Event ID: 3968105) -> Number of islands: 1
# Event 132 (Event ID: 3968113) -> Number of islands: 2
# Event 133 (Event ID: 4001601) -> Number of islands: 1
# Event 134 (Event ID: 4004008) -> Number of islands: 1
# Event 135 (Event ID: 4024205) -> Number of islands: 1
# Event 136 (Event ID: 4030202) -> Number of islands: 1
# Event 137 (Event ID: 4042216) -> Number of islands: 1
# Event 138 (Event ID: 4045416) -> Number of islands: 1
# Event 139 (Event ID: 4074101) -> Number of islands: 1
# Event 140 (Event ID: 4074102) -> Number of islands: 1
# Event 141 (Event ID: 4144409) -> Number of islands: 1
# Event 142 (Event ID: 4164713) -> Number of islands: 1
# Event 143 (Event ID: 4234106) -> Number of islands: 1
# Event 144 (Event ID: 4253105) -> Number of islands: 1
# Event 145 (Event ID: 4253116) -> Number of islands: 1
# Event 146 (Event ID: 4256114) -> Number of islands: 1
# Event 147 (Event ID: 4316100) -> Number of islands: 3
# Event 148 (Event ID: 4316108) -> Number of islands: 1
# Event 149 (Event ID: 4329114) -> Number of islands: 1
# Event 150 (Event ID: 4349908) -> Number of islands: 1
# Event 151 (Event ID: 4414803) -> Number of islands: 1
# Event 152 (Event ID: 4426300) -> Number of islands: 1
# Event 153 (Event ID: 4426312) -> Number of islands: 1
# Event 154 (Event ID: 4426316) -> Number of islands: 1
# Event 155 (Event ID: 4429312) -> Number of islands: 2
# Event 156 (Event ID: 4504105) -> Number of islands: 1
# Event 157 (Event ID: 4504111) -> Number of islands: 2
# Event 158 (Event ID: 4505813) -> Number of islands: 1
# Event 159 (Event ID: 4509915) -> Number of islands: 2
# Event 160 (Event ID: 4599414) -> Number of islands: 1
# Event 161 (Event ID: 4674606) -> Number of islands: 1
# Event 162 (Event ID: 4729116) -> Number of islands: 2
# Event 163 (Event ID: 4730306) -> Number of islands: 2
# Event 164 (Event ID: 4735513) -> Number of islands: 2
# Event 165 (Event ID: 4735516) -> Number of islands: 1
# Event 166 (Event ID: 4764900) -> Number of islands: 2
# Event 167 (Event ID: 4794601) -> Number of islands: 1
# Event 168 (Event ID: 4885017) -> Number of islands: 1
# Event 169 (Event ID: 4962817) -> Number of islands: 1
# Event 170 (Event ID: 4976400) -> Number of islands: 1
# Event 171 (Event ID: 7414) -> Number of islands: 1
# Event 172 (Event ID: 81009) -> Number of islands: 1
# Event 173 (Event ID: 153400) -> Number of islands: 1
# Event 174 (Event ID: 153412) -> Number of islands: 1
# Event 175 (Event ID: 179913) -> Number of islands: 1
# Event 176 (Event ID: 206817) -> Number of islands: 1
# Event 177 (Event ID: 216903) -> Number of islands: 1
# Event 178 (Event ID: 216909) -> Number of islands: 1
# Event 179 (Event ID: 216914) -> Number of islands: 1
# Event 180 (Event ID: 223109) -> Number of islands: 1
# Event 181 (Event ID: 245611) -> Number of islands: 1
# Event 182 (Event ID: 273400) -> Number of islands: 1
# Event 183 (Event ID: 273414) -> Number of islands: 1
# Event 184 (Event ID: 278303) -> Number of islands: 1
# Event 185 (Event ID: 299809) -> Number of islands: 1
# Event 186 (Event ID: 375310) -> Number of islands: 2
# Event 187 (Event ID: 419507) -> Number of islands: 1
# Event 188 (Event ID: 462017) -> Number of islands: 1
# Event 189 (Event ID: 488815) -> Number of islands: 1
# Event 190 (Event ID: 541706) -> Number of islands: 1
# Event 191 (Event ID: 542704) -> Number of islands: 1
# Event 192 (Event ID: 579601) -> Number of islands: 2
# Event 193 (Event ID: 579612) -> Number of islands: 2
# Event 194 (Event ID: 585702) -> Number of islands: 1
# Event 195 (Event ID: 592303) -> Number of islands: 1
# Event 196 (Event ID: 592315) -> Number of islands: 1
# Event 197 (Event ID: 635618) -> Number of islands: 1
# Event 198 (Event ID: 670301) -> Number of islands: 1
# Event 199 (Event ID: 688301) -> Number of islands: 1
# Event 200 (Event ID: 694716) -> Number of islands: 1
# Event 201 (Event ID: 749107) -> Number of islands: 1
# Event 202 (Event ID: 782815) -> Number of islands: 1
# Event 203 (Event ID: 807205) -> Number of islands: 1
# Event 204 (Event ID: 876214) -> Number of islands: 1
# Event 205 (Event ID: 908404) -> Number of islands: 1
# Event 206 (Event ID: 910207) -> Number of islands: 1
# Event 207 (Event ID: 910215) -> Number of islands: 1
# Event 208 (Event ID: 910218) -> Number of islands: 2
# Event 209 (Event ID: 953402) -> Number of islands: 1
# Event 210 (Event ID: 1019119) -> Number of islands: 1
# Event 211 (Event ID: 1078917) -> Number of islands: 1
# Event 212 (Event ID: 1082813) -> Number of islands: 1
# Event 213 (Event ID: 1088804) -> Number of islands: 1
# Event 214 (Event ID: 1090908) -> Number of islands: 2
# Event 215 (Event ID: 1095901) -> Number of islands: 1
# Event 216 (Event ID: 1095905) -> Number of islands: 1
# Event 217 (Event ID: 1113216) -> Number of islands: 1
# Event 218 (Event ID: 1123408) -> Number of islands: 1
# Event 219 (Event ID: 1133706) -> Number of islands: 1
# Event 220 (Event ID: 1203400) -> Number of islands: 1
# Event 221 (Event ID: 1203412) -> Number of islands: 1
# Event 222 (Event ID: 1207402) -> Number of islands: 1
# Event 223 (Event ID: 1207404) -> Number of islands: 1
# Event 224 (Event ID: 1265106) -> Number of islands: 1
# Event 225 (Event ID: 1304908) -> Number of islands: 2
# Event 226 (Event ID: 1339105) -> Number of islands: 1
# Event 227 (Event ID: 1389903) -> Number of islands: 1
# Event 228 (Event ID: 1412616) -> Number of islands: 2
# Event 229 (Event ID: 1444801) -> Number of islands: 1
# Event 230 (Event ID: 1444812) -> Number of islands: 1
# Event 231 (Event ID: 1444818) -> Number of islands: 1
# Event 232 (Event ID: 1450604) -> Number of islands: 1
# Event 233 (Event ID: 1514601) -> Number of islands: 2
# Event 234 (Event ID: 1589016) -> Number of islands: 2
# Event 235 (Event ID: 1593602) -> Number of islands: 1
# Event 236 (Event ID: 1593605) -> Number of islands: 2
# Event 237 (Event ID: 1610201) -> Number of islands: 2
# Event 238 (Event ID: 1799114) -> Number of islands: 1
# Event 239 (Event ID: 1842900) -> Number of islands: 1
# Event 240 (Event ID: 1890400) -> Number of islands: 1
# Event 241 (Event ID: 1970502) -> Number of islands: 1
# Event 242 (Event ID: 1970508) -> Number of islands: 1
# Event 243 (Event ID: 1982107) -> Number of islands: 1
# Event 244 (Event ID: 2003204) -> Number of islands: 1
# Event 245 (Event ID: 2086410) -> Number of islands: 1
# Event 246 (Event ID: 2328919) -> Number of islands: 1
# Event 247 (Event ID: 2363508) -> Number of islands: 1
# Event 248 (Event ID: 2375805) -> Number of islands: 1
# Event 249 (Event ID: 2380603) -> Number of islands: 1
# Event 250 (Event ID: 2405710) -> Number of islands: 1
# Event 251 (Event ID: 2497218) -> Number of islands: 2
# Event 252 (Event ID: 2516910) -> Number of islands: 1
# Event 253 (Event ID: 2547200) -> Number of islands: 1
# Event 254 (Event ID: 2547208) -> Number of islands: 1
# Event 255 (Event ID: 2559802) -> Number of islands: 1
# Event 256 (Event ID: 2559803) -> Number of islands: 1
# Event 257 (Event ID: 2559806) -> Number of islands: 1
# Event 258 (Event ID: 2559810) -> Number of islands: 2
# Event 259 (Event ID: 2568016) -> Number of islands: 1
# Event 260 (Event ID: 2614401) -> Number of islands: 2
# Event 261 (Event ID: 2661204) -> Number of islands: 1
# Event 262 (Event ID: 2676113) -> Number of islands: 1
# Event 263 (Event ID: 2682304) -> Number of islands: 2
# Event 264 (Event ID: 2688007) -> Number of islands: 0
# Event 265 (Event ID: 2688012) -> Number of islands: 1
# Event 266 (Event ID: 2805016) -> Number of islands: 1
# Event 267 (Event ID: 2906407) -> Number of islands: 1
# Event 268 (Event ID: 2937214) -> Number of islands: 1
# Event 269 (Event ID: 3047003) -> Number of islands: 1
# Event 270 (Event ID: 3047016) -> Number of islands: 1
# Event 271 (Event ID: 3048712) -> Number of islands: 1
# Event 272 (Event ID: 3062314) -> Number of islands: 3
# Event 273 (Event ID: 3087105) -> Number of islands: 2
# Event 274 (Event ID: 3143705) -> Number of islands: 1
# Event 275 (Event ID: 3181100) -> Number of islands: 1
# Event 276 (Event ID: 3181110) -> Number of islands: 1
# Event 277 (Event ID: 3222708) -> Number of islands: 1
# Event 278 (Event ID: 3241903) -> Number of islands: 1
# Event 279 (Event ID: 3241917) -> Number of islands: 2
# Event 280 (Event ID: 3277316) -> Number of islands: 1
# Event 281 (Event ID: 3283207) -> Number of islands: 1
# Event 282 (Event ID: 3303716) -> Number of islands: 1
# Event 283 (Event ID: 3346314) -> Number of islands: 1
# Event 284 (Event ID: 3346319) -> Number of islands: 1
# Event 285 (Event ID: 3378211) -> Number of islands: 1
# Event 286 (Event ID: 3411119) -> Number of islands: 1
# Event 287 (Event ID: 3564615) -> Number of islands: 1
# Event 288 (Event ID: 3718004) -> Number of islands: 1
# Event 289 (Event ID: 3718505) -> Number of islands: 1
# Event 290 (Event ID: 3730212) -> Number of islands: 1
# Event 291 (Event ID: 3791713) -> Number of islands: 1
# Event 292 (Event ID: 3794604) -> Number of islands: 2
# Event 293 (Event ID: 3820810) -> Number of islands: 1
# Event 294 (Event ID: 3820814) -> Number of islands: 1
# Event 295 (Event ID: 3935810) -> Number of islands: 1
# Event 296 (Event ID: 3944718) -> Number of islands: 2
# Event 297 (Event ID: 3992101) -> Number of islands: 1
# Event 298 (Event ID: 4036104) -> Number of islands: 1
# Event 299 (Event ID: 4036803) -> Number of islands: 1
# Event 300 (Event ID: 4134510) -> Number of islands: 1
# Event 301 (Event ID: 4143802) -> Number of islands: 1
# Event 302 (Event ID: 4204014) -> Number of islands: 2
# Event 303 (Event ID: 4218502) -> Number of islands: 1
# Event 304 (Event ID: 4296306) -> Number of islands: 1
# Event 305 (Event ID: 4296310) -> Number of islands: 1
# Event 306 (Event ID: 4338610) -> Number of islands: 1
# Event 307 (Event ID: 4496807) -> Number of islands: 1
# Event 308 (Event ID: 4496815) -> Number of islands: 1
# Event 309 (Event ID: 4690202) -> Number of islands: 1
# Event 310 (Event ID: 4690215) -> Number of islands: 0
# Event 311 (Event ID: 4746908) -> Number of islands: 1
# Event 312 (Event ID: 4778610) -> Number of islands: 1
# Event 313 (Event ID: 4812604) -> Number of islands: 2
# Event 314 (Event ID: 4812700) -> Number of islands: 1
# Event 315 (Event ID: 4826417) -> Number of islands: 1
# Event 316 (Event ID: 4859812) -> Number of islands: 1
# Event 317 (Event ID: 4932517) -> Number of islands: 3
# Event 318 (Event ID: 4962419) -> Number of islands: 1
# Event 319 (Event ID: 18306) -> Number of islands: 4
# Event 320 (Event ID: 116511) -> Number of islands: 1
# Event 321 (Event ID: 211504) -> Number of islands: 1
# Event 322 (Event ID: 294500) -> Number of islands: 2
# Event 323 (Event ID: 340803) -> Number of islands: 1
# Event 324 (Event ID: 362708) -> Number of islands: 1
# Event 325 (Event ID: 362710) -> Number of islands: 2
# Event 326 (Event ID: 398119) -> Number of islands: 1
# Event 327 (Event ID: 434507) -> Number of islands: 1
# Event 328 (Event ID: 434514) -> Number of islands: 1
# Event 329 (Event ID: 486508) -> Number of islands: 1
# Event 330 (Event ID: 486513) -> Number of islands: 1
# Event 331 (Event ID: 590704) -> Number of islands: 1
# Event 332 (Event ID: 595610) -> Number of islands: 1
# Event 333 (Event ID: 693209) -> Number of islands: 1
# Event 334 (Event ID: 718017) -> Number of islands: 1
# Event 335 (Event ID: 764904) -> Number of islands: 2
# Event 336 (Event ID: 844002) -> Number of islands: 1
# Event 337 (Event ID: 861810) -> Number of islands: 1
# Event 338 (Event ID: 901216) -> Number of islands: 1
# Event 339 (Event ID: 901410) -> Number of islands: 1
# Event 340 (Event ID: 966709) -> Number of islands: 1
# Event 341 (Event ID: 1006004) -> Number of islands: 1
# Event 342 (Event ID: 1033812) -> Number of islands: 1
# Event 343 (Event ID: 1035102) -> Number of islands: 2
# Event 344 (Event ID: 1162608) -> Number of islands: 1
# Event 345 (Event ID: 1162616) -> Number of islands: 2
# Event 346 (Event ID: 1178606) -> Number of islands: 1
# Event 347 (Event ID: 1275302) -> Number of islands: 1
# Event 348 (Event ID: 1306306) -> Number of islands: 1
# Event 349 (Event ID: 1306311) -> Number of islands: 1
# Event 350 (Event ID: 1313311) -> Number of islands: 1
# Event 351 (Event ID: 1316916) -> Number of islands: 1
# Event 352 (Event ID: 1380203) -> Number of islands: 2
# Event 353 (Event ID: 1409814) -> Number of islands: 1
# Event 354 (Event ID: 1430019) -> Number of islands: 1
# Event 355 (Event ID: 1439409) -> Number of islands: 1
# Event 356 (Event ID: 1498705) -> Number of islands: 1
# Event 357 (Event ID: 1532205) -> Number of islands: 1
# Event 358 (Event ID: 1552107) -> Number of islands: 2
# Event 359 (Event ID: 1609115) -> Number of islands: 2
# Event 360 (Event ID: 1654509) -> Number of islands: 1
# Event 361 (Event ID: 1721906) -> Number of islands: 1
# Event 362 (Event ID: 1746211) -> Number of islands: 1
# Event 363 (Event ID: 1787713) -> Number of islands: 1
# Event 364 (Event ID: 1787715) -> Number of islands: 1
# Event 365 (Event ID: 1839404) -> Number of islands: 1
# Event 366 (Event ID: 1857902) -> Number of islands: 1
# Event 367 (Event ID: 1857911) -> Number of islands: 1
# Event 368 (Event ID: 1859103) -> Number of islands: 2
# Event 369 (Event ID: 1869710) -> Number of islands: 1
# Event 370 (Event ID: 1878809) -> Number of islands: 2
# Event 371 (Event ID: 2056206) -> Number of islands: 1
# Event 372 (Event ID: 2081002) -> Number of islands: 2
# Event 373 (Event ID: 2081008) -> Number of islands: 1
# Event 374 (Event ID: 2096216) -> Number of islands: 1
# Event 375 (Event ID: 2096218) -> Number of islands: 2
# Event 376 (Event ID: 2151904) -> Number of islands: 2
# Event 377 (Event ID: 2151905) -> Number of islands: 2
# Event 378 (Event ID: 2190911) -> Number of islands: 1
# Event 379 (Event ID: 2267013) -> Number of islands: 1
# Event 380 (Event ID: 2359500) -> Number of islands: 1
# Event 381 (Event ID: 2476116) -> Number of islands: 1
# Event 382 (Event ID: 2476118) -> Number of islands: 1
# Event 383 (Event ID: 2531504) -> Number of islands: 1
# Event 384 (Event ID: 2567107) -> Number of islands: 1
# Event 385 (Event ID: 2597806) -> Number of islands: 1
# Event 386 (Event ID: 2709800) -> Number of islands: 1
# Event 387 (Event ID: 2768000) -> Number of islands: 1
# Event 388 (Event ID: 2768008) -> Number of islands: 1
# Event 389 (Event ID: 2821515) -> Number of islands: 1
# Event 390 (Event ID: 2871106) -> Number of islands: 1
# Event 391 (Event ID: 2871116) -> Number of islands: 1
# Event 392 (Event ID: 2891208) -> Number of islands: 1
# Event 393 (Event ID: 2899418) -> Number of islands: 1
# Event 394 (Event ID: 2906713) -> Number of islands: 1
# Event 395 (Event ID: 2945106) -> Number of islands: 3
# Event 396 (Event ID: 2945118) -> Number of islands: 1
# Event 397 (Event ID: 3056517) -> Number of islands: 1
# Event 398 (Event ID: 3072108) -> Number of islands: 3
# Event 399 (Event ID: 3094511) -> Number of islands: 1
# Event 400 (Event ID: 3114113) -> Number of islands: 1
# Event 401 (Event ID: 3172516) -> Number of islands: 1
# Event 402 (Event ID: 3194103) -> Number of islands: 1
# Event 403 (Event ID: 3199318) -> Number of islands: 1
# Event 404 (Event ID: 3221418) -> Number of islands: 0
# Event 405 (Event ID: 3285007) -> Number of islands: 1
# Event 406 (Event ID: 3296710) -> Number of islands: 2
# Event 407 (Event ID: 3329503) -> Number of islands: 1
# Event 408 (Event ID: 3369212) -> Number of islands: 1
# Event 409 (Event ID: 3406602) -> Number of islands: 3
# Event 410 (Event ID: 3428216) -> Number of islands: 1
# Event 411 (Event ID: 3429613) -> Number of islands: 1
# Event 412 (Event ID: 3455906) -> Number of islands: 1
# Event 413 (Event ID: 3492817) -> Number of islands: 1
# Event 414 (Event ID: 3497414) -> Number of islands: 1
# Event 415 (Event ID: 3497415) -> Number of islands: 1
# Event 416 (Event ID: 3499102) -> Number of islands: 1
# Event 417 (Event ID: 3499113) -> Number of islands: 1
# Event 418 (Event ID: 3532412) -> Number of islands: 2
# Event 419 (Event ID: 3591309) -> Number of islands: 1
# Event 420 (Event ID: 3612513) -> Number of islands: 1
# Event 421 (Event ID: 3630208) -> Number of islands: 2
# Event 422 (Event ID: 3630218) -> Number of islands: 1
# Event 423 (Event ID: 3708607) -> Number of islands: 1
# Event 424 (Event ID: 3708619) -> Number of islands: 2
# Event 425 (Event ID: 3715418) -> Number of islands: 1
# Event 426 (Event ID: 3887903) -> Number of islands: 1
# Event 427 (Event ID: 3909312) -> Number of islands: 1
# Event 428 (Event ID: 3924500) -> Number of islands: 1
# Event 429 (Event ID: 3926310) -> Number of islands: 1
# Event 430 (Event ID: 3938402) -> Number of islands: 3
# Event 431 (Event ID: 3961710) -> Number of islands: 1
# Event 432 (Event ID: 3990817) -> Number of islands: 1
# Event 433 (Event ID: 3995506) -> Number of islands: 2
# Event 434 (Event ID: 4006202) -> Number of islands: 1
# Event 435 (Event ID: 4021412) -> Number of islands: 1
# Event 436 (Event ID: 4057309) -> Number of islands: 1
# Event 437 (Event ID: 4082008) -> Number of islands: 1
# Event 438 (Event ID: 4176114) -> Number of islands: 1
# Event 439 (Event ID: 4204601) -> Number of islands: 2
# Event 440 (Event ID: 4204602) -> Number of islands: 2
# Event 441 (Event ID: 4204610) -> Number of islands: 2
# Event 442 (Event ID: 4208619) -> Number of islands: 1
# Event 443 (Event ID: 4211903) -> Number of islands: 2
# Event 444 (Event ID: 4212107) -> Number of islands: 1
# Event 445 (Event ID: 4262104) -> Number of islands: 1
# Event 446 (Event ID: 4312119) -> Number of islands: 1
# Event 447 (Event ID: 4341415) -> Number of islands: 2
# Event 448 (Event ID: 4410600) -> Number of islands: 1
# Event 449 (Event ID: 4415809) -> Number of islands: 1
# Event 450 (Event ID: 4460413) -> Number of islands: 1
# Event 451 (Event ID: 4469603) -> Number of islands: 1
# Event 452 (Event ID: 4542910) -> Number of islands: 1
# Event 453 (Event ID: 4545403) -> Number of islands: 1
# Event 454 (Event ID: 4550719) -> Number of islands: 1
# Event 455 (Event ID: 4579106) -> Number of islands: 1
# Event 456 (Event ID: 4579112) -> Number of islands: 2
# Event 457 (Event ID: 4613100) -> Number of islands: 1
# Event 458 (Event ID: 4626601) -> Number of islands: 1
# Event 459 (Event ID: 4630103) -> Number of islands: 1
# Event 460 (Event ID: 4675803) -> Number of islands: 1
# Event 461 (Event ID: 4698709) -> Number of islands: 1
# Event 462 (Event ID: 4698716) -> Number of islands: 1
# Event 463 (Event ID: 4725619) -> Number of islands: 1
# Event 464 (Event ID: 4823416) -> Number of islands: 1
# Event 465 (Event ID: 4851316) -> Number of islands: 1
# Event 466 (Event ID: 4895911) -> Number of islands: 1
# Event 467 (Event ID: 4946702) -> Number of islands: 2
# Event 468 (Event ID: 35511) -> Number of islands: 1
# Event 469 (Event ID: 49905) -> Number of islands: 1
# Event 470 (Event ID: 56305) -> Number of islands: 1
# Event 471 (Event ID: 106311) -> Number of islands: 1
# Event 472 (Event ID: 107610) -> Number of islands: 1
# Event 473 (Event ID: 127103) -> Number of islands: 1
# Event 474 (Event ID: 360711) -> Number of islands: 1
# Event 475 (Event ID: 360717) -> Number of islands: 1
# Event 476 (Event ID: 360718) -> Number of islands: 1
# Event 477 (Event ID: 372301) -> Number of islands: 1
# Event 478 (Event ID: 451507) -> Number of islands: 1
# Event 479 (Event ID: 497219) -> Number of islands: 1
# Event 480 (Event ID: 517303) -> Number of islands: 1
# Event 481 (Event ID: 517309) -> Number of islands: 1
# Event 482 (Event ID: 517311) -> Number of islands: 1
# Event 483 (Event ID: 517319) -> Number of islands: 1
# Event 484 (Event ID: 631210) -> Number of islands: 1
# Event 485 (Event ID: 796114) -> Number of islands: 1
# Event 486 (Event ID: 821719) -> Number of islands: 0
# Event 487 (Event ID: 844317) -> Number of islands: 1
# Event 488 (Event ID: 894008) -> Number of islands: 1
# Event 489 (Event ID: 929305) -> Number of islands: 2
# Event 490 (Event ID: 934602) -> Number of islands: 1
# Event 491 (Event ID: 939200) -> Number of islands: 1
# Event 492 (Event ID: 939800) -> Number of islands: 1
# Event 493 (Event ID: 1013403) -> Number of islands: 1
# Event 494 (Event ID: 1054115) -> Number of islands: 2
# Event 495 (Event ID: 1071300) -> Number of islands: 1
# Event 496 (Event ID: 1091517) -> Number of islands: 2
# Event 497 (Event ID: 1115902) -> Number of islands: 1
# Event 498 (Event ID: 1115909) -> Number of islands: 1
# Event 499 (Event ID: 1117202) -> Number of islands: 1
# Event 500 (Event ID: 1157700) -> Number of islands: 1
# Event 501 (Event ID: 1157708) -> Number of islands: 1
# Event 502 (Event ID: 1195404) -> Number of islands: 1
# Event 503 (Event ID: 1218814) -> Number of islands: 2
# Event 504 (Event ID: 1218817) -> Number of islands: 2
# Event 505 (Event ID: 1222010) -> Number of islands: 1
# Event 506 (Event ID: 1235202) -> Number of islands: 1
# Event 507 (Event ID: 1348218) -> Number of islands: 1
# Event 508 (Event ID: 1385806) -> Number of islands: 2
# Event 509 (Event ID: 1385809) -> Number of islands: 0
# Event 510 (Event ID: 1459608) -> Number of islands: 1
# Event 511 (Event ID: 1459613) -> Number of islands: 2
# Event 512 (Event ID: 1478905) -> Number of islands: 1
# Event 513 (Event ID: 1517602) -> Number of islands: 1
# Event 514 (Event ID: 1544113) -> Number of islands: 0
# Event 515 (Event ID: 1588201) -> Number of islands: 1
# Event 516 (Event ID: 1695403) -> Number of islands: 1
# Event 517 (Event ID: 1759611) -> Number of islands: 1
# Event 518 (Event ID: 1765515) -> Number of islands: 1
# Event 519 (Event ID: 1807009) -> Number of islands: 1
# Event 520 (Event ID: 1941604) -> Number of islands: 1
# Event 521 (Event ID: 2061112) -> Number of islands: 1
# Event 522 (Event ID: 2093413) -> Number of islands: 1
# Event 523 (Event ID: 2123706) -> Number of islands: 2
# Event 524 (Event ID: 2147017) -> Number of islands: 1
# Event 525 (Event ID: 2153808) -> Number of islands: 2
# Event 526 (Event ID: 2160314) -> Number of islands: 2
# Event 527 (Event ID: 2160316) -> Number of islands: 1
# Event 528 (Event ID: 2165713) -> Number of islands: 1
# Event 529 (Event ID: 2201615) -> Number of islands: 2
# Event 530 (Event ID: 2207009) -> Number of islands: 1
# Event 531 (Event ID: 2275710) -> Number of islands: 1
# Event 532 (Event ID: 2276616) -> Number of islands: 1
# Event 533 (Event ID: 2277209) -> Number of islands: 1
# Event 534 (Event ID: 2291004) -> Number of islands: 1
# Event 535 (Event ID: 2304813) -> Number of islands: 1
# Event 536 (Event ID: 2318006) -> Number of islands: 1
# Event 537 (Event ID: 2371503) -> Number of islands: 1
# Event 538 (Event ID: 2389010) -> Number of islands: 1
# Event 539 (Event ID: 2427919) -> Number of islands: 1
# Event 540 (Event ID: 2505319) -> Number of islands: 1
# Event 541 (Event ID: 2520709) -> Number of islands: 1
# Event 542 (Event ID: 2634717) -> Number of islands: 1
# Event 543 (Event ID: 2705403) -> Number of islands: 2
# Event 544 (Event ID: 2783411) -> Number of islands: 1
# Event 545 (Event ID: 2788409) -> Number of islands: 1
# Event 546 (Event ID: 2813315) -> Number of islands: 2
# Event 547 (Event ID: 2863706) -> Number of islands: 1
# Event 548 (Event ID: 2925518) -> Number of islands: 3
# Event 549 (Event ID: 2926606) -> Number of islands: 1
# Event 550 (Event ID: 2940916) -> Number of islands: 1
# Event 551 (Event ID: 2945206) -> Number of islands: 1
# Event 552 (Event ID: 2958305) -> Number of islands: 1
# Event 553 (Event ID: 3022502) -> Number of islands: 2
# Event 554 (Event ID: 3022914) -> Number of islands: 2
# Event 555 (Event ID: 3090704) -> Number of islands: 1
# Event 556 (Event ID: 3100701) -> Number of islands: 2
# Event 557 (Event ID: 3152000) -> Number of islands: 2
# Event 558 (Event ID: 3152006) -> Number of islands: 1
# Event 559 (Event ID: 3242810) -> Number of islands: 1
# Event 560 (Event ID: 3285915) -> Number of islands: 1
# Event 561 (Event ID: 3318909) -> Number of islands: 1
# Event 562 (Event ID: 3327611) -> Number of islands: 1
# Event 563 (Event ID: 3368210) -> Number of islands: 1
# Event 564 (Event ID: 3384419) -> Number of islands: 1
# Event 565 (Event ID: 3404318) -> Number of islands: 1
# Event 566 (Event ID: 3416904) -> Number of islands: 1
# Event 567 (Event ID: 3416912) -> Number of islands: 1
# Event 568 (Event ID: 3445713) -> Number of islands: 1
# Event 569 (Event ID: 3492408) -> Number of islands: 1
# Event 570 (Event ID: 3586703) -> Number of islands: 1
# Event 571 (Event ID: 3588910) -> Number of islands: 1
# Event 572 (Event ID: 3602801) -> Number of islands: 1
# Event 573 (Event ID: 3605502) -> Number of islands: 1
# Event 574 (Event ID: 3605508) -> Number of islands: 1
# Event 575 (Event ID: 3633617) -> Number of islands: 1
# Event 576 (Event ID: 3698705) -> Number of islands: 1
# Event 577 (Event ID: 3698715) -> Number of islands: 1
# Event 578 (Event ID: 3713106) -> Number of islands: 2
# Event 579 (Event ID: 3713117) -> Number of islands: 2
# Event 580 (Event ID: 3713119) -> Number of islands: 1
# Event 581 (Event ID: 3735818) -> Number of islands: 1
# Event 582 (Event ID: 3743612) -> Number of islands: 1
# Event 583 (Event ID: 3753817) -> Number of islands: 1
# Event 584 (Event ID: 3757416) -> Number of islands: 1
# Event 585 (Event ID: 3859612) -> Number of islands: 1
# Event 586 (Event ID: 3874519) -> Number of islands: 1
# Event 587 (Event ID: 3882805) -> Number of islands: 1
# Event 588 (Event ID: 3898206) -> Number of islands: 1
# Event 589 (Event ID: 3902202) -> Number of islands: 1
# Event 590 (Event ID: 3914212) -> Number of islands: 1
# Event 591 (Event ID: 3937600) -> Number of islands: 1
# Event 592 (Event ID: 3953209) -> Number of islands: 1
# Event 593 (Event ID: 3962206) -> Number of islands: 1
# Event 594 (Event ID: 3963005) -> Number of islands: 2
# Event 595 (Event ID: 3963007) -> Number of islands: 1
# Event 596 (Event ID: 3967901) -> Number of islands: 1
# Event 597 (Event ID: 3982201) -> Number of islands: 1
# Event 598 (Event ID: 4140703) -> Number of islands: 1
# Event 599 (Event ID: 4148809) -> Number of islands: 1
# Event 600 (Event ID: 4183209) -> Number of islands: 1
# Event 601 (Event ID: 4213317) -> Number of islands: 1
# Event 602 (Event ID: 4241905) -> Number of islands: 1
# Event 603 (Event ID: 4261001) -> Number of islands: 1
# Event 604 (Event ID: 4261014) -> Number of islands: 1
# Event 605 (Event ID: 4266010) -> Number of islands: 1
# Event 606 (Event ID: 4335500) -> Number of islands: 1
# Event 607 (Event ID: 4385715) -> Number of islands: 1
# Event 608 (Event ID: 4486313) -> Number of islands: 1
# Event 609 (Event ID: 4542110) -> Number of islands: 1
# Event 610 (Event ID: 4583713) -> Number of islands: 1
# Event 611 (Event ID: 4601408) -> Number of islands: 2
# Event 612 (Event ID: 4603717) -> Number of islands: 1
# Event 613 (Event ID: 4670102) -> Number of islands: 1
# Event 614 (Event ID: 4670118) -> Number of islands: 1
# Event 615 (Event ID: 4691014) -> Number of islands: 1
# Event 616 (Event ID: 4701916) -> Number of islands: 1
# Event 617 (Event ID: 4701917) -> Number of islands: 1
# Event 618 (Event ID: 4802418) -> Number of islands: 1
# Event 619 (Event ID: 4835002) -> Number of islands: 1
# Event 620 (Event ID: 4880514) -> Number of islands: 1
# Event 621 (Event ID: 4989816) -> Number of islands: 1
# Event 622 (Event ID: 4995514) -> Number of islands: 1
# Event 623 (Event ID: 62500) -> Number of islands: 1
# Event 624 (Event ID: 62512) -> Number of islands: 1
# Event 625 (Event ID: 92501) -> Number of islands: 1
# Event 626 (Event ID: 141117) -> Number of islands: 1
# Event 627 (Event ID: 141119) -> Number of islands: 1
# Event 628 (Event ID: 148505) -> Number of islands: 1
# Event 629 (Event ID: 152811) -> Number of islands: 1
# Event 630 (Event ID: 152812) -> Number of islands: 1
# Event 631 (Event ID: 182415) -> Number of islands: 1
# Event 632 (Event ID: 254309) -> Number of islands: 1
# Event 633 (Event ID: 324106) -> Number of islands: 1
# Event 634 (Event ID: 336302) -> Number of islands: 1
# Event 635 (Event ID: 339919) -> Number of islands: 1
# Event 636 (Event ID: 344404) -> Number of islands: 1
# Event 637 (Event ID: 407701) -> Number of islands: 2
# Event 638 (Event ID: 600903) -> Number of islands: 1
# Event 639 (Event ID: 616704) -> Number of islands: 1
# Event 640 (Event ID: 621301) -> Number of islands: 1
# Event 641 (Event ID: 689208) -> Number of islands: 1
# Event 642 (Event ID: 733618) -> Number of islands: 1
# Event 643 (Event ID: 750212) -> Number of islands: 1
# Event 644 (Event ID: 751804) -> Number of islands: 4
# Event 645 (Event ID: 751814) -> Number of islands: 2
# Event 646 (Event ID: 811110) -> Number of islands: 1
# Event 647 (Event ID: 827911) -> Number of islands: 1
# Event 648 (Event ID: 938104) -> Number of islands: 1
# Event 649 (Event ID: 1007000) -> Number of islands: 1
# Event 650 (Event ID: 1007002) -> Number of islands: 1
# Event 651 (Event ID: 1014707) -> Number of islands: 2
# Event 652 (Event ID: 1024013) -> Number of islands: 1
# Event 653 (Event ID: 1062314) -> Number of islands: 2
# Event 654 (Event ID: 1064216) -> Number of islands: 1
# Event 655 (Event ID: 1064217) -> Number of islands: 1
# Event 656 (Event ID: 1095718) -> Number of islands: 1
# Event 657 (Event ID: 1115703) -> Number of islands: 1
# Event 658 (Event ID: 1177419) -> Number of islands: 2
# Event 659 (Event ID: 1246108) -> Number of islands: 1
# Event 660 (Event ID: 1246114) -> Number of islands: 1
# Event 661 (Event ID: 1246118) -> Number of islands: 1
# Event 662 (Event ID: 1254618) -> Number of islands: 1
# Event 663 (Event ID: 1255000) -> Number of islands: 2
# Event 664 (Event ID: 1266205) -> Number of islands: 1
# Event 665 (Event ID: 1266814) -> Number of islands: 1
# Event 666 (Event ID: 1266819) -> Number of islands: 1
# Event 667 (Event ID: 1293305) -> Number of islands: 1
# Event 668 (Event ID: 1308913) -> Number of islands: 0
# Event 669 (Event ID: 1331608) -> Number of islands: 1
# Event 670 (Event ID: 1364410) -> Number of islands: 1
# Event 671 (Event ID: 1364414) -> Number of islands: 1
# Event 672 (Event ID: 1433812) -> Number of islands: 1
# Event 673 (Event ID: 1434704) -> Number of islands: 1
# Event 674 (Event ID: 1444810) -> Number of islands: 1
# Event 675 (Event ID: 1548202) -> Number of islands: 1
# Event 676 (Event ID: 1548216) -> Number of islands: 1
# Event 677 (Event ID: 1558003) -> Number of islands: 1
# Event 678 (Event ID: 1621008) -> Number of islands: 1
# Event 679 (Event ID: 1629607) -> Number of islands: 1
# Event 680 (Event ID: 1679001) -> Number of islands: 1
# Event 681 (Event ID: 1679009) -> Number of islands: 3
# Event 682 (Event ID: 1705019) -> Number of islands: 2
# Event 683 (Event ID: 1725703) -> Number of islands: 1
# Event 684 (Event ID: 1745311) -> Number of islands: 1
# Event 685 (Event ID: 1747317) -> Number of islands: 1
# Event 686 (Event ID: 1749811) -> Number of islands: 1
# Event 687 (Event ID: 1749812) -> Number of islands: 1
# Event 688 (Event ID: 1759000) -> Number of islands: 1
# Event 689 (Event ID: 1766300) -> Number of islands: 1
# Event 690 (Event ID: 1796515) -> Number of islands: 1
# Event 691 (Event ID: 1799802) -> Number of islands: 1
# Event 692 (Event ID: 1799816) -> Number of islands: 1
# Event 693 (Event ID: 1819701) -> Number of islands: 1
# Event 694 (Event ID: 1819703) -> Number of islands: 1
# Event 695 (Event ID: 1843615) -> Number of islands: 1
# Event 696 (Event ID: 2002006) -> Number of islands: 1
# Event 697 (Event ID: 2021813) -> Number of islands: 0
# Event 698 (Event ID: 2073105) -> Number of islands: 3
# Event 699 (Event ID: 2083111) -> Number of islands: 1
# Event 700 (Event ID: 2217816) -> Number of islands: 1
# Event 701 (Event ID: 2319802) -> Number of islands: 1
# Event 702 (Event ID: 2319812) -> Number of islands: 1
# Event 703 (Event ID: 2319817) -> Number of islands: 1
# Event 704 (Event ID: 2324704) -> Number of islands: 1
# Event 705 (Event ID: 2337119) -> Number of islands: 1
# Event 706 (Event ID: 2340513) -> Number of islands: 1
# Event 707 (Event ID: 2344518) -> Number of islands: 1
# Event 708 (Event ID: 2411906) -> Number of islands: 1
# Event 709 (Event ID: 2452310) -> Number of islands: 1
# Event 710 (Event ID: 2466905) -> Number of islands: 1
# Event 711 (Event ID: 2529612) -> Number of islands: 1
# Event 712 (Event ID: 2557907) -> Number of islands: 2
# Event 713 (Event ID: 2658817) -> Number of islands: 1
# Event 714 (Event ID: 2706700) -> Number of islands: 1
# Event 715 (Event ID: 2706714) -> Number of islands: 1
# Event 716 (Event ID: 2745905) -> Number of islands: 1
# Event 717 (Event ID: 2752712) -> Number of islands: 1
# Event 718 (Event ID: 2755010) -> Number of islands: 2
# Event 719 (Event ID: 2763119) -> Number of islands: 1
# Event 720 (Event ID: 2801603) -> Number of islands: 1
# Event 721 (Event ID: 2801607) -> Number of islands: 3
# Event 722 (Event ID: 2801614) -> Number of islands: 1
# Event 723 (Event ID: 2860003) -> Number of islands: 1
# Event 724 (Event ID: 2886714) -> Number of islands: 1
# Event 725 (Event ID: 2959012) -> Number of islands: 1
# Event 726 (Event ID: 2994119) -> Number of islands: 1
# Event 727 (Event ID: 3048707) -> Number of islands: 1
# Event 728 (Event ID: 3181017) -> Number of islands: 1
# Event 729 (Event ID: 3274103) -> Number of islands: 1
# Event 730 (Event ID: 3312104) -> Number of islands: 1
# Event 731 (Event ID: 3316401) -> Number of islands: 1
# Event 732 (Event ID: 3355500) -> Number of islands: 1
# Event 733 (Event ID: 3373006) -> Number of islands: 2
# Event 734 (Event ID: 3383104) -> Number of islands: 1
# Event 735 (Event ID: 3407716) -> Number of islands: 2
# Event 736 (Event ID: 3410114) -> Number of islands: 1
# Event 737 (Event ID: 3458305) -> Number of islands: 1
# Event 738 (Event ID: 3502904) -> Number of islands: 1
# Event 739 (Event ID: 3521700) -> Number of islands: 1
# Event 740 (Event ID: 3536004) -> Number of islands: 1
# Event 741 (Event ID: 3561900) -> Number of islands: 1
# Event 742 (Event ID: 3561911) -> Number of islands: 1
# Event 743 (Event ID: 3561912) -> Number of islands: 1
# Event 744 (Event ID: 3571411) -> Number of islands: 1
# Event 745 (Event ID: 3585508) -> Number of islands: 1
# Event 746 (Event ID: 3594911) -> Number of islands: 1
# Event 747 (Event ID: 3654601) -> Number of islands: 1
# Event 748 (Event ID: 3702309) -> Number of islands: 3
# Event 749 (Event ID: 3737213) -> Number of islands: 1
# Event 750 (Event ID: 3814316) -> Number of islands: 1
# Event 751 (Event ID: 3895017) -> Number of islands: 1
# Event 752 (Event ID: 4013515) -> Number of islands: 1
# Event 753 (Event ID: 4018603) -> Number of islands: 1
# Event 754 (Event ID: 4018618) -> Number of islands: 1
# Event 755 (Event ID: 4031907) -> Number of islands: 1
# Event 756 (Event ID: 4043419) -> Number of islands: 1
# Event 757 (Event ID: 4048813) -> Number of islands: 2
# Event 758 (Event ID: 4089000) -> Number of islands: 1
# Event 759 (Event ID: 4094514) -> Number of islands: 1
# Event 760 (Event ID: 4149509) -> Number of islands: 1
# Event 761 (Event ID: 4151003) -> Number of islands: 2
# Event 762 (Event ID: 4206612) -> Number of islands: 1
# Event 763 (Event ID: 4215301) -> Number of islands: 1
# Event 764 (Event ID: 4215303) -> Number of islands: 1
# Event 765 (Event ID: 4238815) -> Number of islands: 1
# Event 766 (Event ID: 4286510) -> Number of islands: 1
# Event 767 (Event ID: 4286519) -> Number of islands: 1
# Event 768 (Event ID: 4361310) -> Number of islands: 2
# Event 769 (Event ID: 4388008) -> Number of islands: 2
# Event 770 (Event ID: 4463613) -> Number of islands: 0
# Event 771 (Event ID: 4520518) -> Number of islands: 1
# Event 772 (Event ID: 4526208) -> Number of islands: 1
# Event 773 (Event ID: 4597418) -> Number of islands: 1
# Event 774 (Event ID: 4640609) -> Number of islands: 1
# Event 775 (Event ID: 4716407) -> Number of islands: 2
# Event 776 (Event ID: 4742216) -> Number of islands: 1
# Event 777 (Event ID: 4862111) -> Number of islands: 1
# Event 778 (Event ID: 4869414) -> Number of islands: 1
# Event 779 (Event ID: 4869419) -> Number of islands: 1
# Event 780 (Event ID: 4877618) -> Number of islands: 1
# Event 781 (Event ID: 4925208) -> Number of islands: 1
# Event 782 (Event ID: 4935707) -> Number of islands: 2
# Event 783 (Event ID: 4981716) -> Number of islands: 1
# Event 784 (Event ID: 4988615) -> Number of islands: 1
# Event 785 (Event ID: 4993918) -> Number of islands: 1
# Event 786 (Event ID: 145106) -> Number of islands: 1
# Event 787 (Event ID: 145116) -> Number of islands: 1
# Event 788 (Event ID: 162008) -> Number of islands: 1
# Event 789 (Event ID: 192119) -> Number of islands: 1
# Event 790 (Event ID: 192907) -> Number of islands: 2
# Event 791 (Event ID: 192908) -> Number of islands: 1
# Event 792 (Event ID: 245909) -> Number of islands: 1
# Event 793 (Event ID: 341404) -> Number of islands: 1
# Event 794 (Event ID: 341410) -> Number of islands: 1
# Event 795 (Event ID: 351601) -> Number of islands: 1
# Event 796 (Event ID: 480808) -> Number of islands: 1
# Event 797 (Event ID: 499519) -> Number of islands: 1
# Event 798 (Event ID: 552707) -> Number of islands: 2
# Event 799 (Event ID: 555806) -> Number of islands: 1
# Event 800 (Event ID: 555818) -> Number of islands: 1
# Event 801 (Event ID: 586911) -> Number of islands: 1
# Event 802 (Event ID: 743112) -> Number of islands: 2
# Event 803 (Event ID: 766105) -> Number of islands: 1
# Event 804 (Event ID: 812606) -> Number of islands: 1
# Event 805 (Event ID: 936709) -> Number of islands: 1
# Event 806 (Event ID: 947510) -> Number of islands: 1
# Event 807 (Event ID: 955807) -> Number of islands: 1
# Event 808 (Event ID: 966413) -> Number of islands: 1
# Event 809 (Event ID: 968011) -> Number of islands: 2
# Event 810 (Event ID: 992008) -> Number of islands: 1
# Event 811 (Event ID: 1056019) -> Number of islands: 1
# Event 812 (Event ID: 1076506) -> Number of islands: 1
# Event 813 (Event ID: 1207714) -> Number of islands: 1
# Event 814 (Event ID: 1267501) -> Number of islands: 1
# Event 815 (Event ID: 1315704) -> Number of islands: 1
# Event 816 (Event ID: 1315713) -> Number of islands: 1
# Event 817 (Event ID: 1322802) -> Number of islands: 2
# Event 818 (Event ID: 1379314) -> Number of islands: 1
# Event 819 (Event ID: 1428616) -> Number of islands: 1
# Event 820 (Event ID: 1455314) -> Number of islands: 1
# Event 821 (Event ID: 1498014) -> Number of islands: 1
# Event 822 (Event ID: 1529805) -> Number of islands: 1
# Event 823 (Event ID: 1529819) -> Number of islands: 1
# Event 824 (Event ID: 1567901) -> Number of islands: 1
# Event 825 (Event ID: 1567905) -> Number of islands: 2
# Event 826 (Event ID: 1605001) -> Number of islands: 2
# Event 827 (Event ID: 1605005) -> Number of islands: 1
# Event 828 (Event ID: 1609207) -> Number of islands: 2
# Event 829 (Event ID: 1609219) -> Number of islands: 1
# Event 830 (Event ID: 1736118) -> Number of islands: 1
# Event 831 (Event ID: 1739204) -> Number of islands: 1
# Event 832 (Event ID: 1793415) -> Number of islands: 1
# Event 833 (Event ID: 1798810) -> Number of islands: 1
# Event 834 (Event ID: 1844818) -> Number of islands: 1
# Event 835 (Event ID: 1854612) -> Number of islands: 2
# Event 836 (Event ID: 1867802) -> Number of islands: 1
# Event 837 (Event ID: 1907009) -> Number of islands: 1
# Event 838 (Event ID: 1975614) -> Number of islands: 1
# Event 839 (Event ID: 1982603) -> Number of islands: 1
# Event 840 (Event ID: 1997104) -> Number of islands: 1
# Event 841 (Event ID: 2115112) -> Number of islands: 1
# Event 842 (Event ID: 2124802) -> Number of islands: 1
# Event 843 (Event ID: 2126804) -> Number of islands: 1
# Event 844 (Event ID: 2270118) -> Number of islands: 1
# Event 845 (Event ID: 2387901) -> Number of islands: 1
# Event 846 (Event ID: 2403007) -> Number of islands: 1
# Event 847 (Event ID: 2411309) -> Number of islands: 1
# Event 848 (Event ID: 2464603) -> Number of islands: 2
# Event 849 (Event ID: 2475410) -> Number of islands: 1
# Event 850 (Event ID: 2510709) -> Number of islands: 1
# Event 851 (Event ID: 2519704) -> Number of islands: 1
# Event 852 (Event ID: 2533812) -> Number of islands: 2
# Event 853 (Event ID: 2558204) -> Number of islands: 1
# Event 854 (Event ID: 2615116) -> Number of islands: 0
# Event 855 (Event ID: 2640915) -> Number of islands: 2
# Event 856 (Event ID: 2645202) -> Number of islands: 1
# Event 857 (Event ID: 2723115) -> Number of islands: 1
# Event 858 (Event ID: 2830616) -> Number of islands: 1
# Event 859 (Event ID: 2872718) -> Number of islands: 1
# Event 860 (Event ID: 2892311) -> Number of islands: 2
# Event 861 (Event ID: 2892313) -> Number of islands: 1
# Event 862 (Event ID: 2892601) -> Number of islands: 1
# Event 863 (Event ID: 2919304) -> Number of islands: 2
# Event 864 (Event ID: 2919316) -> Number of islands: 2
# Event 865 (Event ID: 2919318) -> Number of islands: 1
# Event 866 (Event ID: 2971510) -> Number of islands: 1
# Event 867 (Event ID: 2971512) -> Number of islands: 1
# Event 868 (Event ID: 2981318) -> Number of islands: 3
# Event 869 (Event ID: 3014113) -> Number of islands: 1
# Event 870 (Event ID: 3043301) -> Number of islands: 1
# Event 871 (Event ID: 3043306) -> Number of islands: 1
# Event 872 (Event ID: 3043317) -> Number of islands: 1
# Event 873 (Event ID: 3065806) -> Number of islands: 1
# Event 874 (Event ID: 3098302) -> Number of islands: 1
# Event 875 (Event ID: 3202903) -> Number of islands: 2
# Event 876 (Event ID: 3259803) -> Number of islands: 2
# Event 877 (Event ID: 3259806) -> Number of islands: 1
# Event 878 (Event ID: 3269500) -> Number of islands: 1
# Event 879 (Event ID: 3269504) -> Number of islands: 1
# Event 880 (Event ID: 3314418) -> Number of islands: 1
# Event 881 (Event ID: 3331212) -> Number of islands: 1
# Event 882 (Event ID: 3352607) -> Number of islands: 1
# Event 883 (Event ID: 3449102) -> Number of islands: 2
# Event 884 (Event ID: 3449116) -> Number of islands: 1
# Event 885 (Event ID: 3449510) -> Number of islands: 1
# Event 886 (Event ID: 3451706) -> Number of islands: 2
# Event 887 (Event ID: 3495503) -> Number of islands: 1
# Event 888 (Event ID: 3502903) -> Number of islands: 1
# Event 889 (Event ID: 3585403) -> Number of islands: 1
# Event 890 (Event ID: 3602108) -> Number of islands: 2
# Event 891 (Event ID: 3623304) -> Number of islands: 1
# Event 892 (Event ID: 3700401) -> Number of islands: 1
# Event 893 (Event ID: 3700403) -> Number of islands: 2
# Event 894 (Event ID: 3700410) -> Number of islands: 1
# ...
# Event 7280 (Event ID: 1127101) -> Number of islands: 1
# Event 7281 (Event ID: 1178505) -> Number of islands: 1
# Event 7282 (Event ID: 1178511) -> Number of islands: 1
# Event 7283 (Event ID: 1186517) -> Number of islands: 1
# Event 7284 (Event ID: 1211316) -> Number of islands: 0
# Event 7285 (Event ID: 1283102) -> Number of islands: 1
# Event 7286 (Event ID: 1285304) -> Number of islands: 2
# Event 7287 (Event ID: 1285318) -> Number of islands: 1
# Event 7288 (Event ID: 1285319) -> Number of islands: 1
# Event 7289 (Event ID: 1361914) -> Number of islands: 1
# Event 7290 (Event ID: 1368519) -> Number of islands: 1
# Event 7291 (Event ID: 1394017) -> Number of islands: 1
# Event 7292 (Event ID: 1556508) -> Number of islands: 3
# Event 7293 (Event ID: 1569412) -> Number of islands: 1
# Event 7294 (Event ID: 1571213) -> Number of islands: 1
# Event 7295 (Event ID: 1657607) -> Number of islands: 1
# Event 7296 (Event ID: 1709308) -> Number of islands: 1
# Event 7297 (Event ID: 1833118) -> Number of islands: 2
# Event 7298 (Event ID: 1901603) -> Number of islands: 2
# Event 7299 (Event ID: 1901610) -> Number of islands: 1
# Event 7300 (Event ID: 1910908) -> Number of islands: 1
# Event 7301 (Event ID: 1910915) -> Number of islands: 1
# Event 7302 (Event ID: 1913202) -> Number of islands: 1
# Event 7303 (Event ID: 1928014) -> Number of islands: 1
# Event 7304 (Event ID: 1935208) -> Number of islands: 1
# Event 7305 (Event ID: 1949604) -> Number of islands: 1
# Event 7306 (Event ID: 1960016) -> Number of islands: 1
# Event 7307 (Event ID: 1994419) -> Number of islands: 1
# Event 7308 (Event ID: 2084306) -> Number of islands: 1
# Event 7309 (Event ID: 2101909) -> Number of islands: 1
# Event 7310 (Event ID: 2184203) -> Number of islands: 1
# Event 7311 (Event ID: 2205308) -> Number of islands: 2
# Event 7312 (Event ID: 2213808) -> Number of islands: 1
# Event 7313 (Event ID: 2213812) -> Number of islands: 1
# Event 7314 (Event ID: 2213817) -> Number of islands: 1
# Event 7315 (Event ID: 2213819) -> Number of islands: 1
# Event 7316 (Event ID: 2232117) -> Number of islands: 1
# Event 7317 (Event ID: 2240802) -> Number of islands: 1
# Event 7318 (Event ID: 2243416) -> Number of islands: 1
# Event 7319 (Event ID: 2275003) -> Number of islands: 1
# Event 7320 (Event ID: 2412107) -> Number of islands: 1
# Event 7321 (Event ID: 2440309) -> Number of islands: 1
# Event 7322 (Event ID: 2477819) -> Number of islands: 1
# Event 7323 (Event ID: 2522400) -> Number of islands: 1
# Event 7324 (Event ID: 2538004) -> Number of islands: 1
# Event 7325 (Event ID: 2589209) -> Number of islands: 1
# Event 7326 (Event ID: 2619205) -> Number of islands: 1
# Event 7327 (Event ID: 2619219) -> Number of islands: 1
# Event 7328 (Event ID: 2620500) -> Number of islands: 1
# Event 7329 (Event ID: 2622303) -> Number of islands: 2
# Event 7330 (Event ID: 2716817) -> Number of islands: 1
# Event 7331 (Event ID: 2785014) -> Number of islands: 1
# Event 7332 (Event ID: 2815607) -> Number of islands: 1
# Event 7333 (Event ID: 2864003) -> Number of islands: 1
# Event 7334 (Event ID: 2864017) -> Number of islands: 1
# Event 7335 (Event ID: 2864018) -> Number of islands: 1
# Event 7336 (Event ID: 2918308) -> Number of islands: 2
# Event 7337 (Event ID: 2977510) -> Number of islands: 1
# Event 7338 (Event ID: 2977514) -> Number of islands: 1
# Event 7339 (Event ID: 2977517) -> Number of islands: 1
# Event 7340 (Event ID: 3056116) -> Number of islands: 2
# Event 7341 (Event ID: 3067409) -> Number of islands: 2
# Event 7342 (Event ID: 3075805) -> Number of islands: 1
# Event 7343 (Event ID: 3091005) -> Number of islands: 1
# Event 7344 (Event ID: 3091010) -> Number of islands: 1
# Event 7345 (Event ID: 3141103) -> Number of islands: 1
# Event 7346 (Event ID: 3237612) -> Number of islands: 1
# Event 7347 (Event ID: 3283409) -> Number of islands: 1
# Event 7348 (Event ID: 3306200) -> Number of islands: 3
# Event 7349 (Event ID: 3306203) -> Number of islands: 1
# Event 7350 (Event ID: 3328605) -> Number of islands: 2
# Event 7351 (Event ID: 3328713) -> Number of islands: 1
# Event 7352 (Event ID: 3382612) -> Number of islands: 3
# Event 7353 (Event ID: 3488718) -> Number of islands: 1
# Event 7354 (Event ID: 3511103) -> Number of islands: 1
# Event 7355 (Event ID: 3511112) -> Number of islands: 2
# Event 7356 (Event ID: 3531208) -> Number of islands: 1
# Event 7357 (Event ID: 3602205) -> Number of islands: 1
# Event 7358 (Event ID: 3615513) -> Number of islands: 1
# Event 7359 (Event ID: 3622605) -> Number of islands: 1
# Event 7360 (Event ID: 3654618) -> Number of islands: 1
# Event 7361 (Event ID: 3657616) -> Number of islands: 1
# Event 7362 (Event ID: 3660019) -> Number of islands: 1
# Event 7363 (Event ID: 3733318) -> Number of islands: 1
# Event 7364 (Event ID: 3746019) -> Number of islands: 0
# Event 7365 (Event ID: 3784008) -> Number of islands: 1
# Event 7366 (Event ID: 3784013) -> Number of islands: 0
# Event 7367 (Event ID: 3889508) -> Number of islands: 1
# Event 7368 (Event ID: 3902806) -> Number of islands: 1
# Event 7369 (Event ID: 3907002) -> Number of islands: 1
# Event 7370 (Event ID: 3907004) -> Number of islands: 1
# Event 7371 (Event ID: 3966603) -> Number of islands: 1
# Event 7372 (Event ID: 3966612) -> Number of islands: 1
# Event 7373 (Event ID: 3984716) -> Number of islands: 2
# Event 7374 (Event ID: 4012102) -> Number of islands: 1
# Event 7375 (Event ID: 4169512) -> Number of islands: 1
# Event 7376 (Event ID: 4171310) -> Number of islands: 1
# Event 7377 (Event ID: 4190107) -> Number of islands: 1
# Event 7378 (Event ID: 4197711) -> Number of islands: 1
# Event 7379 (Event ID: 4214812) -> Number of islands: 1
# Event 7380 (Event ID: 4253310) -> Number of islands: 1
# Event 7381 (Event ID: 4267911) -> Number of islands: 1
# Event 7382 (Event ID: 4295907) -> Number of islands: 1
# Event 7383 (Event ID: 4316011) -> Number of islands: 1
# Event 7384 (Event ID: 4318700) -> Number of islands: 1
# Event 7385 (Event ID: 4356817) -> Number of islands: 1
# Event 7386 (Event ID: 4405408) -> Number of islands: 1
# Event 7387 (Event ID: 4510112) -> Number of islands: 1
# Event 7388 (Event ID: 4524417) -> Number of islands: 1
# Event 7389 (Event ID: 4537706) -> Number of islands: 1
# Event 7390 (Event ID: 4539011) -> Number of islands: 1
# Event 7391 (Event ID: 4557905) -> Number of islands: 1
# Event 7392 (Event ID: 4557913) -> Number of islands: 1
# Event 7393 (Event ID: 4565911) -> Number of islands: 2
# Event 7394 (Event ID: 4566810) -> Number of islands: 1
# Event 7395 (Event ID: 4605604) -> Number of islands: 1
# Event 7396 (Event ID: 4646213) -> Number of islands: 2
# Event 7397 (Event ID: 4646218) -> Number of islands: 2
# Event 7398 (Event ID: 4655805) -> Number of islands: 2
# Event 7399 (Event ID: 4677301) -> Number of islands: 1
# Event 7400 (Event ID: 4697610) -> Number of islands: 1
# Event 7401 (Event ID: 4700703) -> Number of islands: 1
# Event 7402 (Event ID: 4806502) -> Number of islands: 1
# Event 7403 (Event ID: 4806615) -> Number of islands: 0
# Event 7404 (Event ID: 4880604) -> Number of islands: 1
# Event 7405 (Event ID: 4880606) -> Number of islands: 2
# Event 7406 (Event ID: 4952712) -> Number of islands: 1
# Event 7407 (Event ID: 4990900) -> Number of islands: 1
# Event 7408 (Event ID: 7301) -> Number of islands: 1
# Event 7409 (Event ID: 39007) -> Number of islands: 3
# Event 7410 (Event ID: 70616) -> Number of islands: 1
# Event 7411 (Event ID: 71917) -> Number of islands: 1
# Event 7412 (Event ID: 157407) -> Number of islands: 1
# Event 7413 (Event ID: 162909) -> Number of islands: 1
# Event 7414 (Event ID: 182804) -> Number of islands: 1
# Event 7415 (Event ID: 231604) -> Number of islands: 1
# Event 7416 (Event ID: 235206) -> Number of islands: 1
# Event 7417 (Event ID: 236302) -> Number of islands: 2
# Event 7418 (Event ID: 318218) -> Number of islands: 1
# Event 7419 (Event ID: 406218) -> Number of islands: 1
# Event 7420 (Event ID: 499809) -> Number of islands: 1
# Event 7421 (Event ID: 519802) -> Number of islands: 1
# Event 7422 (Event ID: 526019) -> Number of islands: 1
# Event 7423 (Event ID: 528410) -> Number of islands: 2
# Event 7424 (Event ID: 537307) -> Number of islands: 1
# Event 7425 (Event ID: 537308) -> Number of islands: 1
# Event 7426 (Event ID: 560908) -> Number of islands: 1
# Event 7427 (Event ID: 609114) -> Number of islands: 1
# Event 7428 (Event ID: 612016) -> Number of islands: 1
# Event 7429 (Event ID: 766319) -> Number of islands: 1
# Event 7430 (Event ID: 774307) -> Number of islands: 1
# Event 7431 (Event ID: 781608) -> Number of islands: 1
# Event 7432 (Event ID: 784618) -> Number of islands: 1
# Event 7433 (Event ID: 796912) -> Number of islands: 1
# Event 7434 (Event ID: 796913) -> Number of islands: 2
# Event 7435 (Event ID: 803611) -> Number of islands: 1
# Event 7436 (Event ID: 815611) -> Number of islands: 1
# Event 7437 (Event ID: 815612) -> Number of islands: 1
# Event 7438 (Event ID: 884304) -> Number of islands: 1
# Event 7439 (Event ID: 884307) -> Number of islands: 1
# Event 7440 (Event ID: 887501) -> Number of islands: 1
# Event 7441 (Event ID: 911910) -> Number of islands: 1
# Event 7442 (Event ID: 911918) -> Number of islands: 1
# Event 7443 (Event ID: 1018416) -> Number of islands: 1
# Event 7444 (Event ID: 1089702) -> Number of islands: 1
# Event 7445 (Event ID: 1208112) -> Number of islands: 1
# Event 7446 (Event ID: 1233717) -> Number of islands: 1
# Event 7447 (Event ID: 1261919) -> Number of islands: 1
# Event 7448 (Event ID: 1301700) -> Number of islands: 1
# Event 7449 (Event ID: 1312818) -> Number of islands: 1
# Event 7450 (Event ID: 1420619) -> Number of islands: 2
# Event 7451 (Event ID: 1446800) -> Number of islands: 1
# Event 7452 (Event ID: 1466710) -> Number of islands: 2
# Event 7453 (Event ID: 1466711) -> Number of islands: 2
# Event 7454 (Event ID: 1480510) -> Number of islands: 1
# Event 7455 (Event ID: 1508600) -> Number of islands: 3
# Event 7456 (Event ID: 1508602) -> Number of islands: 1
# Event 7457 (Event ID: 1513506) -> Number of islands: 1
# Event 7458 (Event ID: 1513510) -> Number of islands: 1
# Event 7459 (Event ID: 1519012) -> Number of islands: 1
# Event 7460 (Event ID: 1519710) -> Number of islands: 1
# Event 7461 (Event ID: 1532114) -> Number of islands: 1
# Event 7462 (Event ID: 1547906) -> Number of islands: 2
# Event 7463 (Event ID: 1560015) -> Number of islands: 1
# Event 7464 (Event ID: 1568606) -> Number of islands: 1
# Event 7465 (Event ID: 1581006) -> Number of islands: 1
# Event 7466 (Event ID: 1687208) -> Number of islands: 1
# Event 7467 (Event ID: 1706212) -> Number of islands: 1
# Event 7468 (Event ID: 1708516) -> Number of islands: 1
# Event 7469 (Event ID: 1821103) -> Number of islands: 2
# Event 7470 (Event ID: 1920914) -> Number of islands: 1
# Event 7471 (Event ID: 1942508) -> Number of islands: 1
# Event 7472 (Event ID: 1998410) -> Number of islands: 2
# Event 7473 (Event ID: 2016702) -> Number of islands: 1
# Event 7474 (Event ID: 2049806) -> Number of islands: 1
# Event 7475 (Event ID: 2134507) -> Number of islands: 1
# Event 7476 (Event ID: 2161206) -> Number of islands: 1
# Event 7477 (Event ID: 2161212) -> Number of islands: 1
# Event 7478 (Event ID: 2204216) -> Number of islands: 1
# Event 7479 (Event ID: 2250211) -> Number of islands: 1
# Event 7480 (Event ID: 2250505) -> Number of islands: 4
# Event 7481 (Event ID: 2289602) -> Number of islands: 2
# Event 7482 (Event ID: 2300417) -> Number of islands: 1
# Event 7483 (Event ID: 2405216) -> Number of islands: 1
# Event 7484 (Event ID: 2410813) -> Number of islands: 2
# Event 7485 (Event ID: 2435806) -> Number of islands: 1
# Event 7486 (Event ID: 2470709) -> Number of islands: 1
# Event 7487 (Event ID: 2520513) -> Number of islands: 2
# Event 7488 (Event ID: 2555915) -> Number of islands: 1
# Event 7489 (Event ID: 2571804) -> Number of islands: 3
# Event 7490 (Event ID: 2600018) -> Number of islands: 1
# Event 7491 (Event ID: 2645112) -> Number of islands: 1
# Event 7492 (Event ID: 2677104) -> Number of islands: 1
# Event 7493 (Event ID: 2804815) -> Number of islands: 1
# Event 7494 (Event ID: 2885713) -> Number of islands: 1
# Event 7495 (Event ID: 2885714) -> Number of islands: 1
# Event 7496 (Event ID: 2885716) -> Number of islands: 2
# Event 7497 (Event ID: 2885719) -> Number of islands: 3
# Event 7498 (Event ID: 2896313) -> Number of islands: 2
# Event 7499 (Event ID: 2901400) -> Number of islands: 2
# Event 7500 (Event ID: 2901408) -> Number of islands: 1
# Event 7501 (Event ID: 2942215) -> Number of islands: 1
# Event 7502 (Event ID: 3098618) -> Number of islands: 1
# Event 7503 (Event ID: 3162916) -> Number of islands: 2
# Event 7504 (Event ID: 3174318) -> Number of islands: 1
# Event 7505 (Event ID: 3202717) -> Number of islands: 2
# Event 7506 (Event ID: 3227805) -> Number of islands: 2
# Event 7507 (Event ID: 3295200) -> Number of islands: 1
# Event 7508 (Event ID: 3396515) -> Number of islands: 1
# Event 7509 (Event ID: 3467601) -> Number of islands: 1
# Event 7510 (Event ID: 3541312) -> Number of islands: 2
# Event 7511 (Event ID: 3569603) -> Number of islands: 1
# Event 7512 (Event ID: 3614218) -> Number of islands: 1
# Event 7513 (Event ID: 3624018) -> Number of islands: 1
# Event 7514 (Event ID: 3650402) -> Number of islands: 2
# Event 7515 (Event ID: 3650405) -> Number of islands: 1
# Event 7516 (Event ID: 3665902) -> Number of islands: 1
# Event 7517 (Event ID: 3678212) -> Number of islands: 1
# Event 7518 (Event ID: 3736614) -> Number of islands: 1
# Event 7519 (Event ID: 3756211) -> Number of islands: 1
# Event 7520 (Event ID: 3766319) -> Number of islands: 1
# Event 7521 (Event ID: 3828710) -> Number of islands: 1
# Event 7522 (Event ID: 3862303) -> Number of islands: 1
# Event 7523 (Event ID: 3909300) -> Number of islands: 1
# Event 7524 (Event ID: 3922210) -> Number of islands: 1
# Event 7525 (Event ID: 3927002) -> Number of islands: 1
# Event 7526 (Event ID: 4015607) -> Number of islands: 1
# Event 7527 (Event ID: 4026415) -> Number of islands: 1
# Event 7528 (Event ID: 4029105) -> Number of islands: 1
# Event 7529 (Event ID: 4029110) -> Number of islands: 1
# Event 7530 (Event ID: 4029119) -> Number of islands: 1
# Event 7531 (Event ID: 4049406) -> Number of islands: 1
# Event 7532 (Event ID: 4074309) -> Number of islands: 2
# Event 7533 (Event ID: 4120418) -> Number of islands: 1
# Event 7534 (Event ID: 4129905) -> Number of islands: 2
# Event 7535 (Event ID: 4156101) -> Number of islands: 1
# Event 7536 (Event ID: 4197011) -> Number of islands: 1
# Event 7537 (Event ID: 4225111) -> Number of islands: 1
# Event 7538 (Event ID: 4238018) -> Number of islands: 1
# Event 7539 (Event ID: 4248811) -> Number of islands: 1
# Event 7540 (Event ID: 4259503) -> Number of islands: 1
# Event 7541 (Event ID: 4275013) -> Number of islands: 1
# Event 7542 (Event ID: 4305400) -> Number of islands: 0
# Event 7543 (Event ID: 4352208) -> Number of islands: 1
# Event 7544 (Event ID: 4352217) -> Number of islands: 1
# Event 7545 (Event ID: 4370106) -> Number of islands: 2
# Event 7546 (Event ID: 4375606) -> Number of islands: 1
# Event 7547 (Event ID: 4431712) -> Number of islands: 1
# Event 7548 (Event ID: 4476206) -> Number of islands: 1
# Event 7549 (Event ID: 4479510) -> Number of islands: 1
# Event 7550 (Event ID: 4479512) -> Number of islands: 2
# Event 7551 (Event ID: 4491602) -> Number of islands: 2
# Event 7552 (Event ID: 4509808) -> Number of islands: 1
# Event 7553 (Event ID: 4514208) -> Number of islands: 1
# Event 7554 (Event ID: 4522100) -> Number of islands: 2
# Event 7555 (Event ID: 4522107) -> Number of islands: 2
# Event 7556 (Event ID: 4522109) -> Number of islands: 3
# Event 7557 (Event ID: 4589002) -> Number of islands: 2
# Event 7558 (Event ID: 4613119) -> Number of islands: 2
# Event 7559 (Event ID: 4658316) -> Number of islands: 1
# Event 7560 (Event ID: 4665011) -> Number of islands: 1
# Event 7561 (Event ID: 4715406) -> Number of islands: 1
# Event 7562 (Event ID: 4738608) -> Number of islands: 1
# Event 7563 (Event ID: 4739103) -> Number of islands: 1
# Event 7564 (Event ID: 4748918) -> Number of islands: 1
# Event 7565 (Event ID: 4757709) -> Number of islands: 1
# Event 7566 (Event ID: 4792201) -> Number of islands: 1
# Event 7567 (Event ID: 4813717) -> Number of islands: 1
# Event 7568 (Event ID: 4866604) -> Number of islands: 1
# Event 7569 (Event ID: 4918717) -> Number of islands: 1
# Event 7570 (Event ID: 4950802) -> Number of islands: 1

# %% [markdown]
# #### Doing all these for 1000events and then plot the hillas parameter wrt energy

# %%
#The important arrays
energy=[]
width=[]
length=[]
timing_P=[]
geom = subarray.tel[tel_id].camera.geometry

for n in range(1000):

    event = mono_events[n]

    image = event.dl1.tel[tel_id].image
    peak_time = event.dl1.tel[tel_id].peak_time

    # Tailcuts cleaning
    clean_mask = tailcuts_clean(
        geom, image,
        picture_thresh=10,
        boundary_thresh=5
    )

    # Find islands
    n_islands, island_labels = number_of_islands(geom, clean_mask)

    if n_islands == 0:
        continue

    # Brightest island
    mask = largest_island(island_labels)
    final_mask = clean_mask & mask

    clean_image = image * final_mask

    # Hillas parameters
    hillas = hillas_parameters(geom, clean_image)

    # Timing parameters
    timing = timing_parameters(
        geom=geom,
        image=clean_image,
        peak_time=peak_time,
        hillas_parameters=hillas,
        cleaning_mask=final_mask
    )

    # Store values
    energy.append(event.simulation.shower.energy.to_value()) 
    width.append(hillas.width.to_value())
    length.append(hillas.length.to_value())
    timing_P.append(timing.slope.to_value())

# %%
print(len(energy))
print(len(width))

print(type(energy[0]))
print(type(width[0]))
# Out:
# 986
# 986
# <class 'numpy.float64'>
# <class 'numpy.float64'>

# %%
#Plotting the energy vs width
plt.scatter(energy, width, s=5)

plt.xscale("log")
plt.xlabel("Energy (TeV)")
plt.ylabel("Width (deg)")
plt.title("Energy vs Width")

plt.show()

# %%
#Plotting energy with length
plt.scatter(energy, length, s=5)
plt.xscale("log")
plt.xlabel("Energy (TeV)")
plt.ylabel("Length (deg)")
plt.title("Energy vs Length")
plt.show()

# %%
#Plotting the energy vs slope of the timing profile
plt.scatter(energy, timing_P, s=5)
plt.xscale("log")
plt.xlabel("Energy (TeV)")
plt.ylabel("Timing Slope (ns/deg)")
plt.title("Energy vs Timing Slope")
plt.show()
